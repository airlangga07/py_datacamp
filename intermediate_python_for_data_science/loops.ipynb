# %% [markdown]
# # Loops

# %% [markdown]
# ## While loops

# %%
# Initialize offset
offset = -6

# Code the while loop
while offset != 0:
    print("correcting...")
    if offset > 0:
        offset = offset - 1
    else: 
        offset = offset + 1
    print(offset)
# Out:
# correcting...
# -5
# correcting...
# -4
# correcting...
# -3
# correcting...
# -2
# correcting...
# -1
# correcting...
# 0

# %% [markdown]
# ## for loops

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# basic for loops
print('Basic for loops')
for a in areas:
    print(a)
    
# with enumerate to get the index value
print('With enumerate() to get the index value')
for i, a in enumerate(areas):
    print(i, a)
# Out:
# Basic for loops
# 11.25
# 18.0
# 20.0
# 10.75
# 9.5
# With enumerate() to get the index value
# 0 11.25
# 1 18.0
# 2 20.0
# 3 10.75
# 4 9.5

# %% [markdown]
# ## Loop over a dictionary

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 'austria':'vienna' }
          
# Iterate over europe
for k, v in europe.items():
    print('the capital of ' + k + ' is ' + v)
# Out:
# the capital of spain is madrid
# the capital of france is paris
# the capital of germany is berlin
# the capital of norway is oslo
# the capital of italy is rome
# the capital of poland is warsaw
# the capital of austria is vienna

# %% [markdown]
# ## Loop over numpy arrays

# %%
import pandas as pd
import numpy as np

# import the data first
baseball = pd.read_csv('datasets/baseball.csv')
np_height = np.array(baseball['Height'].tolist())
np_weight = np.array(baseball['Weight'].tolist())

# looping over 1D numpy array is the same as normal list
# for x in np_height:
#     print(x)
    
# but to iterate ALL of the elements in 2D array needs a nditer function
np_baseball = np.array([np_height, np_weight])
for x in np.nditer(np_baseball):
    print(x)
# Out:
# 74
# 74
# 72
# 72
# 73
# 69
# 69
# 71
# 76
# 71
# 73
# 73
# 74
# 74
# 69
# 70
# 73
# 75
# 78
# 79
# 76
# 74
# 76
# 72
# 71
# 75
# 77
# 74
# 73
# 74
# 78
# 73
# 75
# 73
# 75
# 75
# 74
# 69
# 71
# 74
# 73
# 73
# 76
# 74
# 74
# 70
# 72
# 77
# 74
# 70
# 73
# 75
# 76
# 76
# 78
# 74
# 74
# 76
# 77
# 81
# 78
# 75
# 77
# 75
# 76
# 74
# 72
# 72
# 75
# 73
# 73
# 73
# 70
# 70
# 70
# 76
# 68
# 71
# 72
# 75
# 75
# 75
# 75
# 68
# 74
# 78
# 71
# 73
# 76
# 74
# 74
# 79
# 75
# 73
# 76
# 74
# 74
# 73
# 72
# 74
# 73
# 74
# 72
# 73
# 69
# 72
# 73
# 75
# 75
# 73
# 72
# 72
# 76
# 74
# 72
# 77
# 74
# 77
# 75
# 76
# 80
# 74
# 74
# 75
# 78
# 73
# 73
# 74
# 75
# 76
# 71
# 73
# 74
# 76
# 76
# 74
# 73
# 74
# 70
# 72
# 73
# 73
# 73
# 73
# 71
# 74
# 74
# 72
# 74
# 71
# 74
# 73
# 75
# 75
# 79
# 73
# 75
# 76
# 74
# 76
# 78
# 74
# 76
# 72
# 74
# 76
# 74
# 75
# 78
# 75
# 72
# 74
# 72
# 74
# 70
# 71
# 70
# 75
# 71
# 71
# 73
# 72
# 71
# 73
# 72
# 75
# 74
# 74
# 75
# 73
# 77
# 73
# 76
# 75
# 74
# 76
# 75
# 73
# 71
# 76
# ...
